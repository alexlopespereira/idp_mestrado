# %% [markdown]
# <a href="https://colab.research.google.com/github/alexlopespereira/idp_mestrado/blob/main/Aulas/Aula5/Aula5_Exercicio_Extra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 5 - Exercícios Extra - Python e Pandas

# %% [markdown]
# ### Onde buscar informações sobre as funções do Pandas
# [https://pandas.pydata.org/docs/](https://pandas.pydata.org/docs/)

# %%
# Importe as bibliotecas pandas e numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ### 5.5 Escreva uma função para mudar o conteúdo de uma coluna de um dataframe de valores do tipo string ('yes' ou 'no') para uma coluna do tipo booleano.
# #### Dica: use a função Series.map

# %%
def change_yes_no(df, col):
    """altere o dataframe na coluna col substituindo 'yes' por True e 'no' por False
    """
    pass

# %%
## Faça seus testes aqui
exam_data = {'name': ['Jose', 'Maria', 'Joao', 'Pedro', 'Emilia',
                      'Marcos', 'Mateus', 'Laura', 'Carlos', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(exam_data, index=labels)
print(change_yes_no(df, 'qualify'))

# %%
# Validação
exam_data = {'name': ['Jose', 'Maria', 'Joao', 'Pedro', 'Emilia',
                      'Marcos', 'Mateus', 'Laura', 'Carlos', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
exam_data2 = {'name': ['Jose', 'Maria', 'Joao', 'Pedro', 'Emilia',
                       'Marcos', 'Mateus', 'Laura', 'Carlos', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'qualify': [True, False, True, False, False, True, True, False, False, True]}
df = pd.DataFrame(exam_data, index=labels)
df2 = pd.DataFrame(exam_data2, index=labels)
result = change_yes_no(df, 'qualify')
assert result.equals(df2)
print("Exercício 5.5 OK!")

# %% [markdown]
# ### 5.6 Escreva uma função para ordenar um DataFrame por colunas de forma descendente, e retornar as top N linhas do DataFrame ordenado
# #### Dica 1: Use a função sort_values do DataFrame. Esta função possui os parâmetros inplace e ascending.

# %%
# Download do dataset Diamonds
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')

# %%
def topN_sorted(df, cols, n):
    """retorne as top n linhas ordenadas por cols
    """
    pass

# %%
## Faça seus testes aqui
print(topN_sorted(diamonds, ['price', 'clarity'], 3))

# %%
# Validação
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
df = pd.DataFrame({'carat':[2.29, 2.0, 1.51],'cut':['Premium', 'Very Good', 'Ideal'],
                   'color':['I', 'G', 'G'],'clarity':['VS2', 'SI1', 'IF'],
                   'depth':[60.8, 63.5, 61.7],'table':[60.0, 56.0, 55.0],
                   'price':[18823, 18818, 18806],'x':[8.5, 7.9, 7.37],
                   'y':[8.47, 7.97, 7.41],'z':[5.16, 5.04, 4.56]},
                 index=[27749, 27748, 27747])
result = topN_sorted(diamonds, ['price', 'clarity'], 3)
assert result.equals(df)
print("Exercício 5.6 OK!")

# %% [markdown]
# ### 5.7 Considerando o dataset Diamonds, escreva uma função para retornar as informações dos diamantes que atendam a especificação x > N e y > N e Z > N
# #### Dica 1: Use o operador & (AND) para realizar a conjunção lógica.

# %%
def filter_xyz(df, n):
    """retorne as linhas que atendam a especificação x > n e y > n e Z > n
    """
    pass

# %%
## Faça seus testes aqui
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
print(filter_xyz(diamonds, 7))

# %%
# Validação
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
result = filter_xyz(diamonds, 7)
expected = {'carat': {24067: 2.0}, 'cut': {24067: 'Premium'}, 'color': {24067: 'H'}, 'clarity': {24067: 'SI2'},
 'depth': {24067: 58.9}, 'table': {24067: 57.0}, 'price': {24067: 12210}, 'x': {24067: 8.09}, 'y': {24067: 58.9},
 'z': {24067: 8.06}}
assert result.to_dict() == expected
print("Exercício 5.7 OK!")

# %% [markdown]
# ### 5.8 Escreva uma função para ordenar uma lista de dicionários usando uma função Lambda.
# #### Dica: use a função sorted. Use o argumento key da função sorted.

# %%
def sort_dict_list(l, chave):
    """retorne a lista ordenada
    """
    pass

# %%
## Faça seus testes aqui
data = [{'nome': ['Pedro'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']},
        {'nome': ['Jose'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']},
        {'nome': ['Maria'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']}]
print(sort_dict_list(data, 'nome'))

# %%
# Validação
data = [{'nome': ['Pedro'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']},
        {'nome': ['Jose'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']},
        {'nome': ['Maria'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']}]
data_sorted = [{'nome': ['Jose'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']},
        {'nome': ['Maria'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']},
        {'nome': ['Pedro'], 'classe': ['V'], 'disciplina': ['portugues', 'matematica', 'ciencia']}]
assert sort_dict_list(data, 'nome') == data_sorted
print("Exercício 5.8 OK!")

# %% [markdown]
# ### 5.9 Escreva uma função para criar uma nova coluna chamada 'segundo' que tenha o segundo maior valor de cada linha de df.
# #### Dica 1: Use a função apply do Dataframe aplicando uma função lambda.
# #### Dica 2: Aplique a função lambda no eixo 1.

# %%
def segundo_maior(df):
    """retorne o dataframe df com uma nova coluna 'segundo' que tenha o segundo maior valor de cada linha
    """
    pass

# %%
## Faça seus testes aqui
data = {'d1': [20, 36, 25, 4, 1, 20, 17, 47, 2, 40],
        'd2': [33, 25, 48, 39, 49, 37, 45, 36, 37, 31],
        'd3': [19, 47, 9, 27, 48, 26, 24, 21, 1, 2]}
df = pd.DataFrame(data)
print(segundo_maior(df))

# %%
# Validação
data = {'d1': [20, 36, 25, 4, 1, 20, 17, 47, 2, 40],
        'd2': [33, 25, 48, 39, 49, 37, 45, 36, 37, 31],
        'd3': [19, 47, 9, 27, 48, 26, 24, 21, 1, 2]}
df = pd.DataFrame(data)
result = segundo_maior(df)
expected = [20, 36, 25, 27, 48, 26, 24, 36, 2, 31]
assert list(result['segundo']) == expected
print("Exercício 5.9 OK!")
