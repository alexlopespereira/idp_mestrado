# %% [markdown]
# <a href="https://colab.research.google.com/github/alexlopespereira/idp_mestrado/blob/main/Aulas/Aula3/Aula3_Exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 3 - Exercícios - Estruturas de Dados Nativas do Python

# %% [markdown]
# ### 3.1 Escreva uma função Python para gerar um dicionário que contenha pares (chave e valor) de números. A chave deve variar de 1 a n, e os valores sejam o valor da chave elevado ao quadrado. #### Exemplo:  Para ```n = 5```#### Resultado Esperado: ```{1: 1, 2: 4, 3: 9, 4: 16, 5: 25}```#### Dica: use a função ```range``` para criar a sequencia de numeros desejados

# %%
def create_dict(n):
    """retorne um dicionário com pares (x, x*x)
    """
    pass

# %%
## Faça seus testes aqui
print(create_dict(5))  # {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
print(create_dict(3))  # {1: 1, 2: 4, 3: 9}

# %%
# Validação
assert create_dict(5) == {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
assert create_dict(3) == {1: 1, 2: 4, 3: 9}
assert create_dict(1) == {1: 1}
print("Exercício 3.1 OK!")

# %% [markdown]
# ### 3.2 Escreva uma função Python para remover itens duplicados de um dicionário, ou seja, cujos valores estejam duplicados.#### Exemplo:  ```d = {1: 1, 2: 1, 3: 9, 4: 1, 5: 25}```#### Resultado Esperado: ```{1: 1, 3: 9, 5: 25}```

# %%
def remove_duplicates(data):
    """retorne um dicionário sem duplicatas
    """
    pass

# %%
## Faça seus testes aqui
print(remove_duplicates({1: 1, 2: 1, 3: 9, 4: 1, 5: 25}))  # {1: 1, 3: 9, 5: 25}

# %%
# Validação
d1 = {1: 1, 2: 1, 3: 9, 4: 1, 5: 25}
assert remove_duplicates(d1) == {1: 1, 3: 9, 5: 25}
print("Exercício 3.2 OK!")

# %% [markdown]
# ### 3.3 Escreva uma função Python para combinar os itens de mesma chave de uma lista de dicionários, somando os valores correspondentes.#### Exemplo:  para ```[{'item': 'carro', 'quantidade': 400}, {'item': 'moto', 'quantidade': 300}, {'item': 'carro', 'quantidade': 750}]```#### Resultado esperado: ```{'carro': 1150, 'moto': 300}```

# %%
def combine_items(item_list):
    """retorne um dicionário combinando (somando) as quantidades do mesmo item
    """
    pass

# %%
## Faça seus testes aqui
ent = [{'item': 'carro', 'quantidade': 400}, 
       {'item': 'moto', 'quantidade': 300}, 
       {'item': 'carro', 'quantidade': 750}]
print(combine_items(ent))  # {'carro': 1150, 'moto': 300}

# %%
# Validação
ent = [{'item': 'carro', 'quantidade': 400}, 
       {'item': 'moto', 'quantidade': 300}, 
       {'item': 'carro', 'quantidade': 750}]
assert combine_items(ent) == {'carro': 1150, 'moto': 300}
print("Exercício 3.3 OK!")

# %% [markdown]
# ### 3.4 Usando um defaultdict, escreva uma função Python para transformar uma lista de listas num dicionário. Os valores repetidos de uma lista devem ser associados a mesma chave do dicionário, como no exemplo abaixo.#### Exemplo:  ```[["carro", 10], ["moto", 20], ["trem", 5], ["carro", 30], ["caminhao", 20]]```#### Resultado esperado: ```{"carro": [10, 30], "moto": [20], "trem": [5], "caminhao": [20]}```

# %%
def dict_from_list(lista):
    """retorne um dicionário com os valores agrupados por chave
    """
    pass

# %%
## Faça seus testes aqui
lista = [["carro", 10], ["moto", 20], ["trem", 5], ["carro", 30], ["caminhao", 20]]
print(dict_from_list(lista))  # {'carro': [10, 30], 'moto': [20], 'trem': [5], 'caminhao': [20]}

# %%
# Validação
lista = [["carro", 10], ["moto", 20], ["trem", 5], ["carro", 30], ["caminhao", 20]]
assert dict_from_list(lista) == {'carro': [10, 30], 'moto': [20], 'trem': [5], 'caminhao': [20]}
print("Exercício 3.4 OK!")
