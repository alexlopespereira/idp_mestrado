# %% [markdown]
# <a href="https://colab.research.google.com/github/alexlopespereira/idp_mestrado/blob/main/Aulas/Aula3/Aula3_Exercicio_Extra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 3 - Exercícios Extra - Estruturas de Dados Nativas do Python

# %% [markdown]
# ### 3.5 Usando um defaultdict, escreva uma função Python para transformar uma lista de listas num dicionário. Os valores repetidos de uma lista devem ser associados a mesma chave do dicionário.
# #### Exemplo:  ```[["carro", 10], ["moto", 20], ["trem", 5], ["carro", 30], ["caminhao", 20]]```
# #### Resultado esperado: ```{"carro": [10, 30], "moto": [20], "trem": [5], "caminhao": [20]}```

# %%
def dict_from_list(lista):
    pass

# %%
## Faça seus testes aqui
lista = [["carro", 10], ["moto", 20], ["trem", 5], ["carro", 30], ["caminhao", 20]]
print(dict_from_list(lista))

# %%
# Validação
lista = [["carro", 10], ["moto", 20], ["trem", 5], ["carro", 30], ["caminhao", 20]]
assert dict_from_list(lista) == {'carro': [10, 30], 'moto': [20], 'trem': [5], 'caminhao': [20]}
print("Exercício 3.5 OK!")

# %% [markdown]
# ### 3.6 Escreva uma função Python para computar o valor total de uma compra de supermercado e dar baixa no estoque. Retorne o valor total da compra.
# #### Se a quantidade do item em estoque for menor do que a quantidade da lista de compra, o estoque restante deve ser vendido.
# #### Exemplo: lista_compras = {"arroz":1, "feijao":2, "macarrao":3}, estoque = {"arroz": 60, "feijao": 30, "macarrao": 1, "farinha": 15}, precos = {"arroz": 4, "feijao": 2, "macarrao": 1.5, "farinha": 3}
# #### Resultado esperado: total = 9.5

# %%
def compra(estoque, precos, lista):
    pass

# %%
## Faça seus testes aqui
lista_compras = {"arroz":1, "feijao":2, "macarrao":3}
estoque = {"arroz": 60, "feijao": 30, "macarrao": 1, "farinha": 15}
precos = {"arroz": 4, "feijao": 2, "macarrao": 1.5, "farinha": 3}
print(compra(estoque, precos, lista_compras))

# %%
# Validação
lista_compras = {"arroz":1, "feijao":2, "macarrao":3}
estoque = {"arroz": 60, "feijao": 30, "macarrao": 1, "farinha": 15}
precos = {"arroz": 4, "feijao": 2, "macarrao": 1.5, "farinha": 3}
assert compra(estoque, precos, lista_compras) == 9.5
print("Exercício 3.6 OK!")

# %% [markdown]
# ### 3.7 Usando o tipo de dados set (conjuntos) do python, crie uma função python que retorne os elementos que não estão na intersecção das duas listas passadas como argumento.
# #### Exemplo: lista1 = ["awerr", "aa", "awyt", "g", "sssaere"], lista2 = ["awerr", "aa", "sssaere", "aabb", "qwerttt", "12345"]
# #### Retorno esperado: ['awyt', 'g', 'aabb', 'qwerttt', '12345']

# %%
def not_union_inters(l1, l2):
    pass

# %%
## Faça seus testes aqui
lista1 = ["awerr", "aa", "awyt", "g", "sssaere"]
lista2 = ["awerr", "aa", "sssaere", "aabb", "qwerttt", "12345"]
print(not_union_inters(lista1, lista2))

# %%
# Validação
lista1 = ["awerr", "aa", "awyt", "g", "sssaere"]
lista2 = ["awerr", "aa", "sssaere", "aabb", "qwerttt", "12345"]
assert set(not_union_inters(lista1, lista2)) == {'12345', 'qwerttt', 'awyt', 'aabb', 'g'}
print("Exercício 3.7 OK!")

# %% [markdown]
# ### 3.8 Crie uma função para gerar tuplas compostas pelos elementos em posições de mesmo índice numa lista e na sua lista reversa.
# #### Exemplo: lista = [1, 4, 6, 10, 5]
# #### Resultado esperado: [(1,5), (4,10), (6,6), (10,4), (5,1)]
# #### Dica: use a função zip

# %%
def lista_tuplas(l):
    pass

# %%
## Faça seus testes aqui
lista = [1, 4, 6, 10, 5]
print(lista_tuplas(lista))

# %%
# Validação
lista = [1, 4, 6, 10, 5]
assert lista_tuplas(lista) == [(1, 5), (4, 10), (6, 6), (10, 4), (5, 1)]
print("Exercício 3.8 OK!")

# %% [markdown]
# ### 3.9 Crie uma função python que receba uma lista como argumento, e usando um list comprehension, crie uma lista de dicionários.
# #### Exemplo: lista = ["azul", "amarelo", "vermelho"]
# #### Resultado esperado: [{"azul": 0}, {"amarelo": 1}, {"vermelho": 2}]

# %%
def lista_dicionarios(l):
    pass

# %%
## Faça seus testes aqui
lista = ["azul", "amarelo", "vermelho"]
print(lista_dicionarios(lista))

# %%
# Validação
lista = ["azul", "amarelo", "vermelho"]
assert lista_dicionarios(lista) == [{'azul': 0}, {'amarelo': 1}, {'vermelho': 2}]
print("Exercício 3.9 OK!")

# %% [markdown]
# ### 3.10 Crie uma função python que receba um dicionário (de alunos e notas) e retorne uma lista com as notas abaixo de um certo valor.
# #### Exemplo: notas = {"Joao": 10, "Jose": 5, "Roberta": 9, "Maria": 6}, minimo = 7
# #### Resultado esperado: [5, 6]

# %%
def nota_baixa(n, minimo):
    pass

# %%
## Faça seus testes aqui
notas = {"Joao": 10, "Jose": 5, "Roberta": 9, "Maria": 6}
print(nota_baixa(notas, 7))

# %%
# Validação
notas = {"Joao": 10, "Jose": 5, "Roberta": 9, "Maria": 6}
assert nota_baixa(notas, 7) == [5, 6]
print("Exercício 3.10 OK!")

# %% [markdown]
# ### Os exercícios a seguir se baseiam num pequeno extrato de um dataset real dos serviços públicos brasileiros (Fiocruz). Execute a próxima célula antes de partir para a resolução.

# %%
# Execute esta célula para criar a variavel servicos
import requests
r = requests.get("https://www.servicos.gov.br/api/v1/servicos/orgao/315")
servicos = r.json()["resposta"]
print(f"Total de serviços: {len(servicos)}")

# %% [markdown]
# ### 3.11 Percorra a lista servicos selecionando os atributos de interesse: nome, sigla, servicoDigital, nomeOrgao. Construa um dicionário de dicionários onde as chaves são o id_servico.

# %%
def atributos_interesse(serv):
    pass

# %%
## Faça seus testes aqui
atr_inter = atributos_interesse(servicos)
print(atr_inter['9031'])

# %%
# Validação
atr_inter = atributos_interesse(servicos)
assert atr_inter['9031']['sigla'] == 'LABFLA'
assert atr_inter['9031']['servicoDigital'] == False
print("Exercício 3.11 OK!")

# %% [markdown]
# ### 3.12 Crie uma função que calcule a porcentagem de serviços digitais presentes no dicionário.

# %%
def calc_porcentagem_digital(servs):
    pass

# %%
## Faça seus testes aqui
atr_inter = atributos_interesse(servicos)
print(calc_porcentagem_digital(atr_inter))

# %%
# Validação
atr_inter = atributos_interesse(servicos)
assert round(calc_porcentagem_digital(atr_inter), 2) == 0.24
print("Exercício 3.12 OK!")
